# %%
# ============================================================
# McCULLOCH-PITTS NEURON - NOT GATE (Fixed Threshold)
# Program by: Pranaya Nakarmi
# Roll No: 1
# ============================================================

print("="*50)
print("  MCP NEURON: NOT GATE")
print("  Program by: Pranaya Nakarmi")
print("  Roll No: 1")
print("="*50)

# MCP Neuron Function for NOT Gate
def mcp_not(x1):
    w1 = -1          # Negative weight for inversion
    T = -0.5         # Negative threshold
    yin = x1 * w1
    if yin >= T:
        return 1
    else:
        return 0

# Test both cases
print("\n  x1  |  y")
print("-"*15)

# Test case 1: 0
y = mcp_not(0)
print(f"  0   |  {y}")

# Test case 2: 1
y = mcp_not(1)
print(f"  1   |  {y}")

print("\n" + "="*50)
print("✅ NOT Gate Implemented Successfully!")
print("="*50)
# Out:
# ==================================================
#   MCP NEURON: NOT GATE
#   Program by: Pranaya Nakarmi
#   Roll No: 1
# ==================================================
#
#   x1  |  y
# ---------------
#   0   |  1
#   1   |  0
#
# ==================================================
# ✅ NOT Gate Implemented Successfully!
# ==================================================

# %%
# ============================================================
# McCULLOCH-PITTS NEURON - NOT GATE (Dynamic Threshold)
# Program by: Pranaya Nakarmi
# Roll No: 1
# ============================================================

print("="*50)
print("  MCP NEURON: NOT GATE (Dynamic Threshold)")
print("  Program by: Pranaya Nakarmi")
print("  Roll No: 1")
print("="*50)

# MCP Neuron Function - T is now dynamic
def mcp_not(x1, T):
    w1 = -1          # Negative weight for inversion
    yin = x1 * w1
    if yin >= T:
        return 1
    else:
        return 0

# Let user set the threshold
T = float(input("Enter threshold value (T): "))

# Expected NOT gate outputs for (0), (1)
target = [1, 0]

inputs = [0, 1]
outputs = []

print(f"\nUsing Threshold T = {T}")
print("\n  x1  |  y")
print("-"*15)

for x1 in inputs:
    y = mcp_not(x1, T)
    outputs.append(y)
    print(f"  {x1}   |  {y}")

print("\n" + "="*50)
if outputs == target:
    print("✅ NOT Gate Implemented Successfully!")
else:
    print("❌ NOT Gate NOT Implemented — output doesn't match target")
    print(f"   Expected: {target}")
    print(f"   Got:      {outputs}")
print("="*50)
# Out:
# ==================================================
#   MCP NEURON: NOT GATE (Dynamic Threshold)
#   Program by: Pranaya Nakarmi
#   Roll No: 1
# ==================================================
#
# Using Threshold T = 1.0
#
#   x1  |  y
# ---------------
#   0   |  0
#   1   |  0
#
# ==================================================
# ❌ NOT Gate NOT Implemented — output doesn't match target
#    Expected: [1, 0]
#    Got:      [0, 0]
# ==================================================
